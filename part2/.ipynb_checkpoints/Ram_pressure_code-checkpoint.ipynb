# %%
#libraries
import h5py
import matplotlib.pyplot as plt
import scienceplots
import numpy as np
import astropy.constants as const
import astropy.units as u
from tqdm import tqdm

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    'font.size': 30,         #tamaño de fuente general
    'axes.titlesize': 30,    #tamaño de fuente para títulos de ejes
    'axes.labelsize': 30,    #tamaño de fuente para etiquetas de ejes
    'xtick.labelsize': 30,   #tamaño de fuente para etiquetas del eje x
    'ytick.labelsize': 30,   #tamaño de fuente para etiquetas del eje y
    'legend.fontsize': 30,   #tamaño de fuente para la leyenda
    'figure.titlesize': 30   #tamaño de fuente para el título de la figura
})

plt.style.use(['science', 'grid'])

# %%
#simulation units
G = 1 #gravity constant
len_sim = 1 #length of simulation in parsec
mass_unit = 1 #mass unit in solar masses
T_sim = 14.9 * np.sqrt((len_sim**3)/mass_unit) #time unit conversion in Myr
vel_sim = 980.4 * (len_sim/(T_sim)) #velocity unit conversion in m/s
print(f'Simulation Time: {T_sim}. Simulation Velocity: {vel_sim}.')
# Out:
# Simulation Time: 14.9. Simulation Velocity: 65.79865771812081.

# %%
#enclosed mass NFW
m_200 = (((5*(10**14))*u.Msun ).to('kg')).value #pasamos masas solares a kg
rho_crit = (9.8*10**(-27)) #kg/m^3
r_200 = ((((3*m_200/(4*np.pi*200*rho_crit))**(1/3)) * u.meter).to('pc')).value
c = 4
r_s = r_200/c

print(f'El valor de r_200: {round((r_200/10**6),3)} en [Mpc]')
print(f'El valor de r_s: {round((r_s/10**6), 3)} en [Mpc]')
# Out:
# El valor de r_200: 1.603 en [Mpc]
# El valor de r_s: 0.401 en [Mpc]

# %%
#initial conditions
x, y, z = r_200/len_sim, 0/len_sim, 0/len_sim
r = np.sqrt(x*x + y*y + z*z)
vx, vy, vz = 0/vel_sim, 300000/vel_sim, 0/vel_sim

N_steps = 10**6
t_orbit = (1*10**3)/T_sim #1 Gyr en cruzar un cumulo
t_end = 10*t_orbit #cantidad de orbitas que daria

t, dt = 0, t_end/N_steps
print(f'Total time of simulation (Physic Units): {round(((t_end*T_sim)/10**3), 2)} [Gyr]')
# Out:
# Total time of simulation (Physic Units): 10.0 [Gyr]

# %%
#orbit simulation
x_arr, y_arr, z_arr = np.ones(N_steps, dtype = float), np.ones(N_steps, dtype = float), np.ones(N_steps, dtype = float)
vx_arr, vy_arr, vz_arr = np.ones(N_steps, dtype = float), np.ones(N_steps, dtype = float), np.ones(N_steps, dtype = float)
t_arr = np.ones(N_steps, dtype = float)
r_arr = np.ones(N_steps, dtype = float)
for i in tqdm(range(0, N_steps), 'Procesando: '):

    x_arr[i], y_arr[i], z_arr[i] = x, y, z
    vx_arr[i], vy_arr[i], vz_arr[i] = vx, vy, vz
    
    r = np.sqrt(x*x + y*y + z*z)
    r_arr[i] = r
    
    s = r/(r_200)
    g_c = 1/ ( np.log(1+c) - (c/(1+c)) )
    m_NFW = ((5*10**14)/mass_unit) * g_c * ( np.log(1 + (c*s)) - ( (c*s)/(1 + c*s) ) )
    
    ax, ay, az = (-(G*m_NFW)/(r**2))*(x/r), (-(G*m_NFW)/(r**2))*(y/r), (-(G*m_NFW)/(r**2))*(z/r)
    vx, vy, vz = vx + ax*dt, vy + ay*dt, vz + az*dt
    x, y, z = x + vx*dt, y + vy*dt, z + vz*dt
    t_arr[i] = t 
    t = i*dt
# Out:
# Procesando: 100%|██████████████████| 1000000/1000000 [00:17<00:00, 58738.48it/s]

# %%
x_arr, y_arr, z_arr = x_arr*len_sim, y_arr*len_sim, z_arr*len_sim
r_arr = r_arr * len_sim
vx_arr, vy_arr, vz_arr = vx_arr*vel_sim, vy_arr*vel_sim, vz_arr*vel_sim
t_arr = t_arr * T_sim

# %%
#radius precision
fig = plt.figure(figsize = (18,8))
gs = fig.add_gridspec(1,2)
ax = gs.subplots()

for i in range(0, 2):
    for spine in ax[i].spines.values():
        spine.set_linewidth(2)
    ax[i].tick_params(axis='both', which='major', labelsize=28, length=10, width=2)
    ax[i].tick_params(axis='both', which='minor', length=5, width=1.5)
    ax[i].minorticks_on()
    
ax[0].plot(x_arr, y_arr, color = 'darkred', lw = 2)
ax[0].set_xlabel('x [pc]')
ax[0].set_ylabel('y [pc]')

ax[1].plot(t_arr/10**3, r_arr/10**6, color = 'darkred', lw = 2)
ax[1].set_xlabel('t [Gyr]')
ax[1].set_ylabel('r [Mpc]')

plt.show()

# %%
short_time = np.where((t_arr < 4000))[0]
max_r = np.where(r_arr[short_time] == np.max(r_arr[short_time]))[0]
min_r = np.where(r_arr[short_time] == np.min(r_arr[short_time]))[0]
t_apo, t_peri = t_arr[max_r][0], t_arr[min_r][0]
r_apo, r_peri = r_arr[max_r][0], r_arr[min_r][0]

print(f't_apo: {t_apo:.2e} [Myr] y t_peri: {t_peri:.2e} [Myr]')
print(f'r_apo: {r_apo:.2e} [pc] y r_peri: {r_peri:.2e} [pc]')
# Out:
# t_apo: 3.54e+03 [Myr] y t_peri: 1.77e+03 [Myr]
# r_apo: 1.60e+06 [pc] y r_peri: 2.05e+05 [pc]

# %%
fig = plt.figure(figsize=(6,5))
ax = fig.subplots()

for i in range(0, 1):
    for spine in ax.spines.values():
        spine.set_linewidth(2)
    ax.tick_params(axis='both', which='major', labelsize=16, length=10, width=2)
    ax.tick_params(axis='both', which='minor', length=5, width=1.5)
    ax.minorticks_on()
    
ax.plot(t_arr/10**3, r_arr/(10**6), color = 'darkred', lw = 2)
ax.set_xlabel('t [Gyr]')
ax.set_ylabel('r [Mpc]')
ax.axvline(t_apo/10**3, color = 'purple', label = r't$_{apo}$', lw = 2, ls = '--')
ax.axvline(t_peri/10**3, color = 'green', label = r't$_{peri}$', lw = 2, ls = '--')
#ax.set_xlim(0, 5000)
ax.legend(framealpha = 0.5, fontsize = 16)

plt.show()

# %%
#Ram Pressure with beta profile
beta = 0.5
r_core = (50000*u.pc).to('m') #meter
rho_0 = (( (2*10**(-26)) * u.g/u.cm**3 ).to('kg/m3') ) #kg/m^3
rho_ICM_arr = rho_0 * ( 1 + (((r_arr*u.pc).to('m'))/r_core)**2 )**(-(3*beta)/2)

M_200 = ( m_200*u.kg ).to('kg')
v_orb = ((np.sqrt(vx_arr*vx_arr + vy_arr*vy_arr + vz_arr*vz_arr))*(u.m/u.s) )
P_ram = rho_ICM_arr*(v_orb**2)

# %%
#print(r_core)
#print(rho_0)
print(rho_ICM_arr)
#print(M_200)
#print(v_orb)
print(P_ram)
# Out:
# [1.10059769e-25 1.10059769e-25 1.10059769e-25 ... 1.28788189e-25
#  1.28787487e-25 1.28786786e-25] kg / m3
# [9.90537917e-15 9.90537918e-15 9.90537921e-15 ... 4.84460709e-14
#  4.84445158e-14 4.84429607e-14] kg / (m s2)

# %%
fig = plt.figure(figsize = (6,14))
gs = fig.add_gridspec(3,1, hspace = 0)
ax = gs.subplots(sharex=True, sharey=False)

for i in range(0, 3):
    for spine in ax[i].spines.values():
        spine.set_linewidth(2)
    ax[i].tick_params(axis='both', which='major', labelsize=16, length=10, width=2)
    ax[i].tick_params(axis='both', which='minor', length=5, width=1.5)
    ax[i].minorticks_on()
print(P_ram.to('dyn / cm2'))
ax[0].plot(t_arr/10**3, rho_ICM_arr.to('Msun/pc3'), lw = 2, color = 'black')
ax[1].plot(t_arr/10**3, v_orb.to('km/s'), lw = 2, color = 'darkred')
ax[2].plot(t_arr/10**3, (P_ram.to('dyn / cm2'))/10**(-9), lw = 2, color = 'peru')

ax[0].set_ylabel(r'$\rho_{_{_{ICM}}}(r)$ [M$_{\odot}$pc$^{-3}$]', fontsize = 20)
ax[1].set_ylabel(r'V$_{orb}$(r) [km s$^{-1}$]', fontsize = 20)
ax[2].set_ylabel(r'P$_{_{_{RAM}}}(r)$ [10$^{-9}$ dyn cm$^{-2}$]', fontsize = 20)


ax[2].set_xlabel('t [Gyr]', fontsize = 20)
plt.show()
# Out:
# [9.90537917e-14 9.90537918e-14 9.90537921e-14 ... 4.84460709e-13
#  4.84445158e-13 4.84429607e-13] dyn / cm2

# %%
#massive galaxy
r_d_massive = (4000*u.pc ).to('m') #meter
m_star_massive = ((1*10**10)*u.Msun ).to('kg') #kg
m_gas_massive = ((1*10**9)*u.Msun).to('kg') #kg

sigma_0_star_massive = m_star_massive/(2*np.pi*(r_d_massive**2))
sigma_0_gas_massive = m_gas_massive/(2*np.pi*(r_d_massive**2))

restoring_force_disk_massive = 2*np.pi*const.G*sigma_0_star_massive*sigma_0_gas_massive
pos_massive = np.where(P_ram > restoring_force_disk_massive)[0][0]
print(f'Ram Pressure Array: {P_ram}')
print('-----------------------------------')
print(f'Restoring Force from Disk (Pressure)(Massive one): {restoring_force_disk_massive}')
print('-----------------------------------')
print(f'Radius in where Ram Pressure is higher (Massive one): {((r_arr[pos_massive]/10**6) * u.Mpc):.2e}')
print(f'Time in where Ram Pressure is higher than Restoring Force (Massive one): {((t_arr[pos_massive]/10**3)*u.Gyr):.2e}')
# Out:
# Ram Pressure Array: [9.90537917e-15 9.90537918e-15 9.90537921e-15 ... 4.84460709e-14
#  4.84445158e-14 4.84429607e-14] kg / (m s2)
# -----------------------------------
# Restoring Force from Disk (Pressure)(Massive one): 1.8096539279820939e-12 kg / (m s2)
# -----------------------------------
# Radius in where Ram Pressure is higher (Massive one): 5.36e-01 Mpc
# Time in where Ram Pressure is higher than Restoring Force (Massive one): 1.52e+00 Gyr

# %%
#lower mass galaxy
r_d_low = (2500*u.pc).to('m') #pc
m_star_low = ((1*10**9)*u.Msun).to('kg') #msun
m_gas_low = ((1*10**9)*u.Msun).to('kg') #msun

sigma_0_star_low = (m_star_low/(2*np.pi*(r_d_low**2)))
sigma_0_gas_low = (m_gas_low/(2*np.pi*(r_d_low**2)))

restoring_force_disk_low = 2*np.pi*const.G*sigma_0_star_low*sigma_0_gas_low
pos_low = np.where(P_ram > restoring_force_disk_low)[0][0]
print(f'Ram Pressure Array: {P_ram}')
print('-----------------------------------')
print(f'Restoring Force from Disk (Pressure)(low one): {restoring_force_disk_low}')
print('-----------------------------------')
print(f'Radius in where Ram Pressure is higher (low one): {((r_arr[pos_low]/10**6) * u.Mpc):.2e}')
print(f'Time in where Ram Pressure is higher than Restoring Force (low one): {((t_arr[pos_low]/10**3)*u.Gyr):.2e}')
# Out:
# Ram Pressure Array: [9.90537917e-15 9.90537918e-15 9.90537921e-15 ... 4.84460709e-14
#  4.84445158e-14 4.84429607e-14] kg / (m s2)
# -----------------------------------
# Restoring Force from Disk (Pressure)(low one): 1.1859747982423446e-12 kg / (m s2)
# -----------------------------------
# Radius in where Ram Pressure is higher (low one): 6.37e-01 Mpc
# Time in where Ram Pressure is higher than Restoring Force (low one): 1.45e+00 Gyr

# %%
fig = plt.figure(figsize = (6,14))
gs = fig.add_gridspec(3,1, hspace = 0)
ax = gs.subplots(sharex=True, sharey=False)

for i in range(0, 3):
    for spine in ax[i].spines.values():
        spine.set_linewidth(2)
    ax[i].tick_params(axis='both', which='major', labelsize=16, length=10, width=2)
    ax[i].tick_params(axis='both', which='minor', length=5, width=1.5)
    ax[i].minorticks_on()

ax[0].plot(t_arr/10**3, rho_ICM_arr, lw = 2, color = 'black')
ax[0].axvline(t_arr[pos_low]/10**3, color = 'darkblue', ls = '--', label = 'Low mass galaxy', lw = 2)
ax[0].axvline(t_arr[pos_massive]/10**3, color = 'darkred', ls = '--', label = 'Massive galaxy', lw = 2)

ax[1].plot(t_arr/10**3, v_orb, lw = 2, color = 'darkred')
ax[1].axvline(t_arr[pos_low]/10**3, color = 'darkblue', ls = '--', lw = 2)
ax[1].axvline(t_arr[pos_massive]/10**3, color = 'darkred', ls = '--', lw = 2)

ax[2].plot(t_arr/10**3, P_ram, lw = 2, color = 'peru')
ax[2].axvline(t_arr[pos_low]/10**3, color = 'darkblue', ls = '--', lw = 2)
ax[2].axvline(t_arr[pos_massive]/10**3, color = 'darkred', ls = '--', lw = 2)

ax[0].set_ylabel(r'$\rho_{_{_{ICM}}}(r)$ [M$_{\odot}$pc$^{-3}$]', fontsize = 20)
ax[1].set_ylabel(r'V$_{orb}$(r) [m s$^{-1}$]', fontsize = 20)
ax[2].set_ylabel(r'P$_{_{_{RAM}}}(r)$ [kg m$^{-1}$ s$^{-2}$]', fontsize = 20)
ax[2].set_xlabel('t [Gyr]', fontsize = 20)

ax[0].legend(fontsize = 15, framealpha = 0.8)
ax[0].set_xlim(1.2,2)
plt.show()
